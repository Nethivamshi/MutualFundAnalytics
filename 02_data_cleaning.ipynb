# %%
import pandas as pd
import os
from pathlib import Path

RAW  = Path('data/raw')
PROC = Path('data/processed')
os.makedirs(PROC, exist_ok=True)

df = pd.read_csv(RAW / '02_nav_history.csv')
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['amfi_code', 'date']).reset_index(drop=True)
df['nav'] = df.groupby('amfi_code')['nav'].ffill()
df = df.drop_duplicates(subset=['amfi_code', 'date'])
df = df[df['nav'] > 0]

print(f"Rows after cleaning: {len(df)}")
df.to_csv(PROC / 'clean_nav.csv', index=False)
print("Saved → data/processed/clean_nav.csv")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 7
#       5 RAW  = Path('data/raw')
#       6 PROC = Path('data/processed')
# ----> 7 os.makedirs(PROC, exist_ok=True)
#       9 df = pd.read_csv(RAW / '02_nav_history.csv')
#      10 df['date'] = pd.to_datetime(df['date'])
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'data/processed'
